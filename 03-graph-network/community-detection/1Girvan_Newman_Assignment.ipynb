# %%
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms.community import girvan_newman

# Load the American College Football dataset
G = nx.football_graph()
print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")

# Q1: Load the dataset (Already provided)

# Q2: Visualize the network
# TODO: Implement a function to visualize the network with different colors for each community

# Q3: Compute basic graph properties
# TODO: Compute and print the number of connected components, degree of each node, and network density

# Q4: Identify the most important nodes
# TODO: Compute and print the top 5 most connected nodes based on degree centrality

# Q5: Implement the Girvan-Newman Algorithm
# TODO: Implement a function to apply the Girvan-Newman algorithm and return the first level of communities

# Q6: List the detected communities
# TODO: Extract and print all detected communities at the first level

# Q7: Visualize the detected communities
# TODO: Modify the visualization to display nodes in different colors based on their detected communities

# Q8: Compare different levels of Girvan-Newman splits
# TODO: Extract and print the number of communities at different levels of splitting

# Q9: Compute modularity scores
# TODO: Compute and print the modularity score for the detected communities

# Main execution area (call implemented functions)
if __name__ == "__main__":
    pass  # TODO: Call the implemented functions here
